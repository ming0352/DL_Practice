# %%
from tensorflow.keras.layers import Input, Conv2D, DepthwiseConv2D, \
     Dense, Concatenate, Add, ReLU, BatchNormalization, AvgPool2D, \
     MaxPool2D, GlobalAvgPool2D, Reshape, Permute, Lambda
from tensorflow.keras import Model

# %%
def stage(x, channels, repetitions, groups):
    x = shufflenet_block(x, channels=channels, strides=2, groups=groups)
    for i in range(repetitions):
        x = shufflenet_block(x, channels=channels, strides=1, groups=groups)
    return x

# %%
def shufflenet_block(tensor, channels, strides, groups):
    x = gconv(tensor, channels=channels//4 , groups=groups)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = channel_shuffle(x, groups)
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)

    if strides == 2:
        channels = channels - tensor.get_shape().as_list()[-1]
    x = Conv2D(channels, kernel_size = 1, strides = (1,1),padding = 'same', groups=groups)(x)
    # x = gconv(x, channels=channels, groups=groups)
    x = BatchNormalization()(x)

    if strides == 1:
        x = Add()([tensor, x])
    else:
        avg = AvgPool2D(pool_size=3, strides=2, padding='same')(tensor)
        x = Concatenate()([avg, x])

    output = ReLU()(x)
    return output

# %%
def gconv(tensor, channels, groups):
    input_ch = tensor.get_shape().as_list()[-1]
    group_ch = input_ch // groups
    output_ch = channels // groups
    groups_list = []

    for i in range(groups):
        group_tensor = tensor[:, :, :, i * group_ch: (i+1) * group_ch]
        # group_tensor = Lambda(lambda x: x[:, :, :, i * group_ch: (i+1) * group_ch])(tensor)
        group_tensor = Conv2D(output_ch, 1)(group_tensor)
        groups_list.append(group_tensor)

    output = Concatenate()(groups_list)
    return output

# %%
def channel_shuffle(x, groups):  
    _, width, height, channels = x.get_shape().as_list()
    group_ch = channels // groups

    x = Reshape([width, height, group_ch, groups])(x)
    x = Permute([1, 2, 4, 3])(x) #transpose
    x = Reshape([width, height, channels])(x)
    return x

# %%
def build_shuffleNet():
    input = Input([224, 224, 3])
    #stage1
    x = Conv2D(filters=24, kernel_size=3, strides=2, padding='same')(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    repetitions = 3, 7, 3
    initial_channels = 240
    groups = 3

    for i, reps in enumerate(repetitions):
        channels = initial_channels * (2**i)
        x = stage(x, channels, reps, groups)
    x = GlobalAvgPool2D()(x)
    output = Dense(1000, activation='softmax')(x)
    model = Model(input, output)    
    return model

# %%
model=build_shuffleNet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 24  672         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 24  96         ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 112, 112, 24  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 24)   0           ['re_lu[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 56, 56, 8)   0           ['max_pooling2d[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, 56, 56, 8)   0           ['max_pooling2d[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_2 (Sl  (None, 56, 56, 8)   0           ['max_pooling2d[0][0]']
#  icingOpLambda)
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 20)   180         ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 20)   180         ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 20)   180         ['tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  concatenate (Concatenate)      (None, 56, 56, 60)   0           ['conv2d_1[0][0]',
#                                                                   'conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 60)  240         ['concatenate[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 56, 56, 60)   0           ['batch_normalization_1[0][0]']
#
#  reshape (Reshape)              (None, 56, 56, 20,   0           ['re_lu_1[0][0]']
#                                 3)
#
#  permute (Permute)              (None, 56, 56, 3, 2  0           ['reshape[0][0]']
#                                 0)
#
#  reshape_1 (Reshape)            (None, 56, 56, 60)   0           ['permute[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 28, 28, 60)  600         ['reshape_1[0][0]']
#  v2D)
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 60)  240         ['depthwise_conv2d[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 216)  4536        ['batch_normalization_2[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 24)  0           ['max_pooling2d[0][0]']
#  ing2D)
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 216)  864        ['conv2d_4[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 240)  0           ['average_pooling2d[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 28, 28, 240)  0           ['concatenate_1[0][0]']
#
#  tf.__operators__.getitem_3 (Sl  (None, 28, 28, 80)  0           ['re_lu_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_4 (Sl  (None, 28, 28, 80)  0           ['re_lu_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_5 (Sl  (None, 28, 28, 80)  0           ['re_lu_2[0][0]']
#  icingOpLambda)
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_4[0][0
#                                                                  ]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_5[0][0
#                                                                  ]']
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 60)   0           ['conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 60)  240         ['concatenate_2[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 28, 28, 60)   0           ['batch_normalization_4[0][0]']
#
#  reshape_2 (Reshape)            (None, 28, 28, 20,   0           ['re_lu_3[0][0]']
#                                 3)
#
#  permute_1 (Permute)            (None, 28, 28, 3, 2  0           ['reshape_2[0][0]']
#                                 0)
#
#  reshape_3 (Reshape)            (None, 28, 28, 60)   0           ['permute_1[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 28, 28, 60)  600         ['reshape_3[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 60)  240         ['depthwise_conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 240)  5040        ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 240)  960        ['conv2d_8[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 28, 28, 240)  0           ['re_lu_2[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 28, 28, 240)  0           ['add[0][0]']
#
#  tf.__operators__.getitem_6 (Sl  (None, 28, 28, 80)  0           ['re_lu_4[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_7 (Sl  (None, 28, 28, 80)  0           ['re_lu_4[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_8 (Sl  (None, 28, 28, 80)  0           ['re_lu_4[0][0]']
#  icingOpLambda)
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
#  concatenate_3 (Concatenate)    (None, 28, 28, 60)   0           ['conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 60)  240         ['concatenate_3[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 28, 28, 60)   0           ['batch_normalization_7[0][0]']
#
#  reshape_4 (Reshape)            (None, 28, 28, 20,   0           ['re_lu_5[0][0]']
#                                 3)
#
#  permute_2 (Permute)            (None, 28, 28, 3, 2  0           ['reshape_4[0][0]']
#                                 0)
#
#  reshape_5 (Reshape)            (None, 28, 28, 60)   0           ['permute_2[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 28, 28, 60)  600         ['reshape_5[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 60)  240         ['depthwise_conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 240)  5040        ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 240)  960        ['conv2d_12[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 240)  0           ['re_lu_4[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 28, 28, 240)  0           ['add_1[0][0]']
#
#  tf.__operators__.getitem_9 (Sl  (None, 28, 28, 80)  0           ['re_lu_6[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_10 (S  (None, 28, 28, 80)  0           ['re_lu_6[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_11 (S  (None, 28, 28, 80)  0           ['re_lu_6[0][0]']
#  licingOpLambda)
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_9[0][0
#                                                                  ]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_10[0][
#                                                                  0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 20)   1620        ['tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 60)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 60)  240         ['concatenate_4[0][0]']
#  ormalization)
#
#  re_lu_7 (ReLU)                 (None, 28, 28, 60)   0           ['batch_normalization_10[0][0]']
#
#  reshape_6 (Reshape)            (None, 28, 28, 20,   0           ['re_lu_7[0][0]']
#                                 3)
#
#  permute_3 (Permute)            (None, 28, 28, 3, 2  0           ['reshape_6[0][0]']
#                                 0)
#
#  reshape_7 (Reshape)            (None, 28, 28, 60)   0           ['permute_3[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 28, 28, 60)  600         ['reshape_7[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 60)  240         ['depthwise_conv2d_3[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 240)  5040        ['batch_normalization_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 240)  960        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 28, 28, 240)  0           ['re_lu_6[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 28, 28, 240)  0           ['add_2[0][0]']
#
#  tf.__operators__.getitem_12 (S  (None, 28, 28, 80)  0           ['re_lu_8[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_13 (S  (None, 28, 28, 80)  0           ['re_lu_8[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_14 (S  (None, 28, 28, 80)  0           ['re_lu_8[0][0]']
#  licingOpLambda)
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 40)   3240        ['tf.__operators__.getitem_12[0][
#                                                                  0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 40)   3240        ['tf.__operators__.getitem_13[0][
#                                                                  0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 40)   3240        ['tf.__operators__.getitem_14[0][
#                                                                  0]']
#
#  concatenate_5 (Concatenate)    (None, 28, 28, 120)  0           ['conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 120)  480        ['concatenate_5[0][0]']
#  ormalization)
#
#  re_lu_9 (ReLU)                 (None, 28, 28, 120)  0           ['batch_normalization_13[0][0]']
#
#  reshape_8 (Reshape)            (None, 28, 28, 40,   0           ['re_lu_9[0][0]']
#                                 3)
#
#  permute_4 (Permute)            (None, 28, 28, 3, 4  0           ['reshape_8[0][0]']
#                                 0)
#
#  reshape_9 (Reshape)            (None, 28, 28, 120)  0           ['permute_4[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 14, 14, 120)  1200       ['reshape_9[0][0]']
#  onv2D)
#
#  batch_normalization_14 (BatchN  (None, 14, 14, 120)  480        ['depthwise_conv2d_4[0][0]']
#  ormalization)
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 240)  9840        ['batch_normalization_14[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 14, 14, 240)  0          ['re_lu_8[0][0]']
#  oling2D)
#
#  batch_normalization_15 (BatchN  (None, 14, 14, 240)  960        ['conv2d_20[0][0]']
#  ormalization)
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 480)  0           ['average_pooling2d_1[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  re_lu_10 (ReLU)                (None, 14, 14, 480)  0           ['concatenate_6[0][0]']
#
#  tf.__operators__.getitem_15 (S  (None, 14, 14, 160)  0          ['re_lu_10[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_16 (S  (None, 14, 14, 160)  0          ['re_lu_10[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_17 (S  (None, 14, 14, 160)  0          ['re_lu_10[0][0]']
#  licingOpLambda)
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_15[0][
#                                                                  0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_16[0][
#                                                                  0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_17[0][
#                                                                  0]']
#
#  concatenate_7 (Concatenate)    (None, 14, 14, 120)  0           ['conv2d_21[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 14, 14, 120)  480        ['concatenate_7[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 14, 14, 120)  0           ['batch_normalization_16[0][0]']
#
#  reshape_10 (Reshape)           (None, 14, 14, 40,   0           ['re_lu_11[0][0]']
#                                 3)
#
#  permute_5 (Permute)            (None, 14, 14, 3, 4  0           ['reshape_10[0][0]']
#                                 0)
#
#  reshape_11 (Reshape)           (None, 14, 14, 120)  0           ['permute_5[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 14, 14, 120)  1200       ['reshape_11[0][0]']
#  onv2D)
#
#  batch_normalization_17 (BatchN  (None, 14, 14, 120)  480        ['depthwise_conv2d_5[0][0]']
#  ormalization)
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 480)  19680       ['batch_normalization_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 14, 14, 480)  1920       ['conv2d_24[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 14, 14, 480)  0           ['re_lu_10[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  re_lu_12 (ReLU)                (None, 14, 14, 480)  0           ['add_3[0][0]']
#
#  tf.__operators__.getitem_18 (S  (None, 14, 14, 160)  0          ['re_lu_12[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_19 (S  (None, 14, 14, 160)  0          ['re_lu_12[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_20 (S  (None, 14, 14, 160)  0          ['re_lu_12[0][0]']
#  licingOpLambda)
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_18[0][
#                                                                  0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_19[0][
#                                                                  0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_20[0][
#                                                                  0]']
#
#  concatenate_8 (Concatenate)    (None, 14, 14, 120)  0           ['conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 14, 14, 120)  480        ['concatenate_8[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 14, 14, 120)  0           ['batch_normalization_19[0][0]']
#
#  reshape_12 (Reshape)           (None, 14, 14, 40,   0           ['re_lu_13[0][0]']
#                                 3)
#
#  permute_6 (Permute)            (None, 14, 14, 3, 4  0           ['reshape_12[0][0]']
#                                 0)
#
#  reshape_13 (Reshape)           (None, 14, 14, 120)  0           ['permute_6[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 14, 14, 120)  1200       ['reshape_13[0][0]']
#  onv2D)
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 120)  480        ['depthwise_conv2d_6[0][0]']
#  ormalization)
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 480)  19680       ['batch_normalization_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 480)  1920       ['conv2d_28[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 14, 14, 480)  0           ['re_lu_12[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  re_lu_14 (ReLU)                (None, 14, 14, 480)  0           ['add_4[0][0]']
#
#  tf.__operators__.getitem_21 (S  (None, 14, 14, 160)  0          ['re_lu_14[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_22 (S  (None, 14, 14, 160)  0          ['re_lu_14[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_23 (S  (None, 14, 14, 160)  0          ['re_lu_14[0][0]']
#  licingOpLambda)
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_21[0][
#                                                                  0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_22[0][
#                                                                  0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_23[0][
#                                                                  0]']
#
#  concatenate_9 (Concatenate)    (None, 14, 14, 120)  0           ['conv2d_29[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 120)  480        ['concatenate_9[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 14, 14, 120)  0           ['batch_normalization_22[0][0]']
#
#  reshape_14 (Reshape)           (None, 14, 14, 40,   0           ['re_lu_15[0][0]']
#                                 3)
#
#  permute_7 (Permute)            (None, 14, 14, 3, 4  0           ['reshape_14[0][0]']
#                                 0)
#
#  reshape_15 (Reshape)           (None, 14, 14, 120)  0           ['permute_7[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 14, 14, 120)  1200       ['reshape_15[0][0]']
#  onv2D)
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 120)  480        ['depthwise_conv2d_7[0][0]']
#  ormalization)
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 480)  19680       ['batch_normalization_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 480)  1920       ['conv2d_32[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 14, 14, 480)  0           ['re_lu_14[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  re_lu_16 (ReLU)                (None, 14, 14, 480)  0           ['add_5[0][0]']
#
#  tf.__operators__.getitem_24 (S  (None, 14, 14, 160)  0          ['re_lu_16[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_25 (S  (None, 14, 14, 160)  0          ['re_lu_16[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_26 (S  (None, 14, 14, 160)  0          ['re_lu_16[0][0]']
#  licingOpLambda)
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_24[0][
#                                                                  0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_25[0][
#                                                                  0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 40)   6440        ['tf.__operators__.getitem_26[0][
#                                                                  0]']
#
#  concatenate_10 (Concatenate)   (None, 14, 14, 120)  0           ['conv2d_33[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 120)  480        ['concatenate_10[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 14, 14, 120)  0           ['batch_normalization_25[0][0]']
#
#  reshape_16 (Reshape)           (None, 14, 14, 40,   0           ['re_lu_17[0][0]']
#                                 3)
#
#  permute_8 (Permute)            (None, 14, 14, 3, 4  0           ['reshape_16[0][0]']
#                                 0)
#
#  reshape_17 (Reshape)           (None, 14, 14, 120)  0           ['permute_8[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 14, 14, 120)  1200       ['reshape_17[0][0]']
#  onv2D)
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 120)  480        ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 480)  19680       ['batch_normalization_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 480)  1920       ['conv2d_36[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 14, 14, 480)  0           ['re_lu_16[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  re_lu_18 (ReLU)                (None, 14, 14, 480)  0           ['add_6[0][0]']
#
#  tf.__operators__.getitem_27 (S  (None, 14, 14, 160)  0          ['re_lu_18[0][0]']
#  licingOpLambda)
# ...
#  concatenate_15 (Concatenate)   (None, 7, 7, 960)    0           ['average_pooling2d_2[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  re_lu_26 (ReLU)                (None, 7, 7, 960)    0           ['concatenate_15[0][0]']
#
#  tf.__operators__.getitem_39 (S  (None, 7, 7, 320)   0           ['re_lu_26[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_40 (S  (None, 7, 7, 320)   0           ['re_lu_26[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_41 (S  (None, 7, 7, 320)   0           ['re_lu_26[0][0]']
#  licingOpLambda)
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_39[0][
#                                                                  0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_40[0][
#                                                                  0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_41[0][
#                                                                  0]']
#
#  concatenate_16 (Concatenate)   (None, 7, 7, 240)    0           ['conv2d_53[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 7, 7, 240)   960         ['concatenate_16[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 7, 7, 240)    0           ['batch_normalization_40[0][0]']
#
#  reshape_26 (Reshape)           (None, 7, 7, 80, 3)  0           ['re_lu_27[0][0]']
#
#  permute_13 (Permute)           (None, 7, 7, 3, 80)  0           ['reshape_26[0][0]']
#
#  reshape_27 (Reshape)           (None, 7, 7, 240)    0           ['permute_13[0][0]']
#
#  depthwise_conv2d_13 (Depthwise  (None, 7, 7, 240)   2400        ['reshape_27[0][0]']
#  Conv2D)
#
#  batch_normalization_41 (BatchN  (None, 7, 7, 240)   960         ['depthwise_conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 960)    77760       ['batch_normalization_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 7, 7, 960)   3840        ['conv2d_56[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 7, 7, 960)    0           ['re_lu_26[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  re_lu_28 (ReLU)                (None, 7, 7, 960)    0           ['add_10[0][0]']
#
#  tf.__operators__.getitem_42 (S  (None, 7, 7, 320)   0           ['re_lu_28[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_43 (S  (None, 7, 7, 320)   0           ['re_lu_28[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_44 (S  (None, 7, 7, 320)   0           ['re_lu_28[0][0]']
#  licingOpLambda)
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_42[0][
#                                                                  0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_43[0][
#                                                                  0]']
#
#  conv2d_59 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_44[0][
#                                                                  0]']
#
#  concatenate_17 (Concatenate)   (None, 7, 7, 240)    0           ['conv2d_57[0][0]',
#                                                                   'conv2d_58[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 240)   960         ['concatenate_17[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 7, 7, 240)    0           ['batch_normalization_43[0][0]']
#
#  reshape_28 (Reshape)           (None, 7, 7, 80, 3)  0           ['re_lu_29[0][0]']
#
#  permute_14 (Permute)           (None, 7, 7, 3, 80)  0           ['reshape_28[0][0]']
#
#  reshape_29 (Reshape)           (None, 7, 7, 240)    0           ['permute_14[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 7, 7, 240)   2400        ['reshape_29[0][0]']
#  Conv2D)
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 240)   960         ['depthwise_conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_60 (Conv2D)             (None, 7, 7, 960)    77760       ['batch_normalization_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 960)   3840        ['conv2d_60[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 7, 7, 960)    0           ['re_lu_28[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  re_lu_30 (ReLU)                (None, 7, 7, 960)    0           ['add_11[0][0]']
#
#  tf.__operators__.getitem_45 (S  (None, 7, 7, 320)   0           ['re_lu_30[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_46 (S  (None, 7, 7, 320)   0           ['re_lu_30[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_47 (S  (None, 7, 7, 320)   0           ['re_lu_30[0][0]']
#  licingOpLambda)
#
#  conv2d_61 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_45[0][
#                                                                  0]']
#
#  conv2d_62 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_46[0][
#                                                                  0]']
#
#  conv2d_63 (Conv2D)             (None, 7, 7, 80)     25680       ['tf.__operators__.getitem_47[0][
#                                                                  0]']
#
#  concatenate_18 (Concatenate)   (None, 7, 7, 240)    0           ['conv2d_61[0][0]',
#                                                                   'conv2d_62[0][0]',
#                                                                   'conv2d_63[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 240)   960         ['concatenate_18[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 7, 7, 240)    0           ['batch_normalization_46[0][0]']
#
#  reshape_30 (Reshape)           (None, 7, 7, 80, 3)  0           ['re_lu_31[0][0]']
#
#  permute_15 (Permute)           (None, 7, 7, 3, 80)  0           ['reshape_30[0][0]']
#
#  reshape_31 (Reshape)           (None, 7, 7, 240)    0           ['permute_15[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 7, 7, 240)   2400        ['reshape_31[0][0]']
#  Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 240)   960         ['depthwise_conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_64 (Conv2D)             (None, 7, 7, 960)    77760       ['batch_normalization_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 960)   3840        ['conv2d_64[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 7, 7, 960)    0           ['re_lu_30[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  re_lu_32 (ReLU)                (None, 7, 7, 960)    0           ['add_12[0][0]']
#
#  global_average_pooling2d (Glob  (None, 960)         0           ['re_lu_32[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1000)         961000      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 1,901,488
# Trainable params: 1,877,008
# Non-trainable params: 24,480
# __________________________________________________________________________________________________

# %%
# from keras.utils import plot_model
# plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
