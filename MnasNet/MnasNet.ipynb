# %%
import tensorflow as tf 
import numpy as np
import pandas as pd 
import os 
from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.applications import xception
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint

# %%
img_height=224
img_width=224
classes=1
batch_size=32
patience=5
ePOCH=10

# %%
train_ds=tf.keras.preprocessing.image_dataset_from_directory(
                                                  '../dataset_cat vs dog/image',
                                                  validation_split=0.3,
                                                  subset="training",
                                                  seed=123,
                                                  image_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  label_mode='binary',
                                                  shuffle=True)
valid_ds=tf.keras.preprocessing.image_dataset_from_directory(
                                                  '../dataset_cat vs dog/image',
                                                  validation_split=0.3,
                                                  subset="validation",
                                                  seed=123,
                                                  image_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  label_mode='binary',
                                                  shuffle=True)
test_ds=tf.keras.preprocessing.image_dataset_from_directory(
                                                  '../dataset_cat vs dog/test',
                                                 # validation_split=0.3,
                                                  # subset="training",
                                                  seed=123,
                                                  image_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  # label_mode='categorical',
                                                  shuffle=False)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 17500 files for training.
# Found 25000 files belonging to 2 classes.
# Using 7500 files for validation.
# Found 12500 files belonging to 1 classes.

# %%
def conv_bn(x, filters, kernel_size, strides=1, activation=True):
    x = tf.keras.layers.Conv2D(filters=filters, 
                               kernel_size=kernel_size, 
                               strides=strides, 
                               padding='SAME')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    if activation:
        x = tf.keras.layers.Activation('relu')(x)
        
    return x

# %%
def depthwiseConv_bn(x, kernel_size, strides):

    x = tf.keras.layers.DepthwiseConv2D(kernel_size, 
                                        padding='same', 
                                        strides=strides)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    return x

# %%
def sepConv_bn_noskip(x, filters, kernel_size, strides=1):
    
    x = depthwiseConv_bn(x, kernel_size=kernel_size, strides=strides)
    x = conv_bn(x, filters=filters, kernel_size=1, strides=1)
    
    return x

# %%
def Squeeze_excitation_layer(x):
    
    inputs = x
    squeeze = inputs.shape[-1]/2
    excitation = inputs.shape[-1]
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(squeeze)(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dense(excitation)(x)
    x = tf.keras.layers.Activation('sigmoid')(x)
    x = tf.keras.layers.Reshape((1, 1, excitation))(x)
    x = inputs * x

    return x

# %%
def MBConv_idskip(x, filters, kernel_size, strides, t, SE=False):
    
    x_input = x
    
    x = conv_bn(x, filters=x.shape[-1] * t, kernel_size=1, strides=1)
    x = depthwiseConv_bn(x, kernel_size=kernel_size, strides=strides)
    if SE:
        x = Squeeze_excitation_layer(x)
    x = conv_bn(x, filters=filters, kernel_size=1, strides=1, activation=False)
    
    if strides==1 and x.shape[3] == x_input.shape[3]:
        return  tf.keras.layers.add([x_input, x])
    else: 
        return x

# %%
def MBConv(x, filters, kernel_size, strides, t, n, SE=False):
    
    x = MBConv_idskip(x, filters, kernel_size, strides, t, SE)
    
    for _ in range(1, n):
        x = MBConv_idskip(x, filters, kernel_size, strides=1, t=t, SE=SE)
        
    return x

# %%
def MnasNet(n_classes=1000):
    inputs = tf.keras.layers.Input(shape=(224, 224, 3))
    x = conv_bn(inputs, 32, kernel_size=3, strides=2)
    x = sepConv_bn_noskip(x, filters=16, kernel_size=3, strides=1)
    x = MBConv(x, filters=24, kernel_size=3, strides=2, t=6, n=2)
    x = MBConv(x, filters=40, kernel_size=5, strides=2, t=3, n=3, SE=True)
    x = MBConv(x, filters=80, kernel_size=3, strides=2, t=6, n=4)
    x = MBConv(x, filters=96, kernel_size=3, strides=1, t=6, n=2, SE=True)
    x = MBConv(x, filters=192, kernel_size=5, strides=2, t=6, n=3, SE=True)
    x = MBConv(x, filters=320, kernel_size=3, strides=1, t=6, n=1)
    
    x = conv_bn(x, filters=1152, kernel_size=1, strides=1)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    predictions = tf.keras.layers.Dense(classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=predictions)
    return model

# %%
model=MnasNet()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_66 (Conv2D)             (None, 112, 112, 32  896         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_98 (BatchN  (None, 112, 112, 32  128        ['conv2d_66[0][0]']
#  ormalization)                  )
#
#  activation_100 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_98[0][0]']
#                                 )
#
#  depthwise_conv2d_32 (Depthwise  (None, 112, 112, 32  320        ['activation_100[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_99 (BatchN  (None, 112, 112, 32  128        ['depthwise_conv2d_32[0][0]']
#  ormalization)                  )
#
#  activation_101 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_99[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 112, 112, 16  528         ['activation_101[0][0]']
#                                 )
#
#  batch_normalization_100 (Batch  (None, 112, 112, 16  64         ['conv2d_67[0][0]']
#  Normalization)                 )
#
#  activation_102 (Activation)    (None, 112, 112, 16  0           ['batch_normalization_100[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 112, 112, 96  1632        ['activation_102[0][0]']
#                                 )
#
#  batch_normalization_101 (Batch  (None, 112, 112, 96  384        ['conv2d_68[0][0]']
#  Normalization)                 )
#
#  activation_103 (Activation)    (None, 112, 112, 96  0           ['batch_normalization_101[0][0]']
#                                 )
#
#  depthwise_conv2d_33 (Depthwise  (None, 56, 56, 96)  960         ['activation_103[0][0]']
#  Conv2D)
#
#  batch_normalization_102 (Batch  (None, 56, 56, 96)  384         ['depthwise_conv2d_33[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 56, 56, 96)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 56, 56, 24)   2328        ['activation_104[0][0]']
#
#  batch_normalization_103 (Batch  (None, 56, 56, 24)  96          ['conv2d_69[0][0]']
#  Normalization)
#
#  conv2d_70 (Conv2D)             (None, 56, 56, 144)  3600        ['batch_normalization_103[0][0]']
#
#  batch_normalization_104 (Batch  (None, 56, 56, 144)  576        ['conv2d_70[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 56, 56, 144)  0           ['batch_normalization_104[0][0]']
#
#  depthwise_conv2d_34 (Depthwise  (None, 56, 56, 144)  1440       ['activation_105[0][0]']
#  Conv2D)
#
#  batch_normalization_105 (Batch  (None, 56, 56, 144)  576        ['depthwise_conv2d_34[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 56, 56, 144)  0           ['batch_normalization_105[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 56, 56, 24)   3480        ['activation_106[0][0]']
#
#  batch_normalization_106 (Batch  (None, 56, 56, 24)  96          ['conv2d_71[0][0]']
#  Normalization)
#
#  add_18 (Add)                   (None, 56, 56, 24)   0           ['batch_normalization_103[0][0]',
#                                                                   'batch_normalization_106[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 56, 56, 72)   1800        ['add_18[0][0]']
#
#  batch_normalization_107 (Batch  (None, 56, 56, 72)  288         ['conv2d_72[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 56, 56, 72)   0           ['batch_normalization_107[0][0]']
#
#  depthwise_conv2d_35 (Depthwise  (None, 28, 28, 72)  1872        ['activation_107[0][0]']
#  Conv2D)
#
#  batch_normalization_108 (Batch  (None, 28, 28, 72)  288         ['depthwise_conv2d_35[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 28, 28, 72)   0           ['batch_normalization_108[0][0]']
#
#  global_average_pooling2d_18 (G  (None, 72)          0           ['activation_108[0][0]']
#  lobalAveragePooling2D)
#
#  dense_34 (Dense)               (None, 36)           2628        ['global_average_pooling2d_18[0][
#                                                                  0]']
#
#  activation_109 (Activation)    (None, 36)           0           ['dense_34[0][0]']
#
#  dense_35 (Dense)               (None, 72)           2664        ['activation_109[0][0]']
#
#  activation_110 (Activation)    (None, 72)           0           ['dense_35[0][0]']
#
#  reshape_16 (Reshape)           (None, 1, 1, 72)     0           ['activation_110[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 28, 28, 72)  0           ['activation_108[0][0]',
#  a)                                                               'reshape_16[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 28, 28, 40)   2920        ['tf.math.multiply_16[0][0]']
#
#  batch_normalization_109 (Batch  (None, 28, 28, 40)  160         ['conv2d_73[0][0]']
#  Normalization)
#
#  conv2d_74 (Conv2D)             (None, 28, 28, 120)  4920        ['batch_normalization_109[0][0]']
#
#  batch_normalization_110 (Batch  (None, 28, 28, 120)  480        ['conv2d_74[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 28, 28, 120)  0           ['batch_normalization_110[0][0]']
#
#  depthwise_conv2d_36 (Depthwise  (None, 28, 28, 120)  3120       ['activation_111[0][0]']
#  Conv2D)
#
#  batch_normalization_111 (Batch  (None, 28, 28, 120)  480        ['depthwise_conv2d_36[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 28, 28, 120)  0           ['batch_normalization_111[0][0]']
#
#  global_average_pooling2d_19 (G  (None, 120)         0           ['activation_112[0][0]']
#  lobalAveragePooling2D)
#
#  dense_36 (Dense)               (None, 60)           7260        ['global_average_pooling2d_19[0][
#                                                                  0]']
#
#  activation_113 (Activation)    (None, 60)           0           ['dense_36[0][0]']
#
#  dense_37 (Dense)               (None, 120)          7320        ['activation_113[0][0]']
#
#  activation_114 (Activation)    (None, 120)          0           ['dense_37[0][0]']
#
#  reshape_17 (Reshape)           (None, 1, 1, 120)    0           ['activation_114[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 28, 28, 120)  0          ['activation_112[0][0]',
#  a)                                                               'reshape_17[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 28, 28, 40)   4840        ['tf.math.multiply_17[0][0]']
#
#  batch_normalization_112 (Batch  (None, 28, 28, 40)  160         ['conv2d_75[0][0]']
#  Normalization)
#
#  add_19 (Add)                   (None, 28, 28, 40)   0           ['batch_normalization_109[0][0]',
#                                                                   'batch_normalization_112[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 28, 28, 120)  4920        ['add_19[0][0]']
#
#  batch_normalization_113 (Batch  (None, 28, 28, 120)  480        ['conv2d_76[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 28, 28, 120)  0           ['batch_normalization_113[0][0]']
#
#  depthwise_conv2d_37 (Depthwise  (None, 28, 28, 120)  3120       ['activation_115[0][0]']
#  Conv2D)
#
#  batch_normalization_114 (Batch  (None, 28, 28, 120)  480        ['depthwise_conv2d_37[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 28, 28, 120)  0           ['batch_normalization_114[0][0]']
#
#  global_average_pooling2d_20 (G  (None, 120)         0           ['activation_116[0][0]']
#  lobalAveragePooling2D)
#
#  dense_38 (Dense)               (None, 60)           7260        ['global_average_pooling2d_20[0][
#                                                                  0]']
#
#  activation_117 (Activation)    (None, 60)           0           ['dense_38[0][0]']
#
#  dense_39 (Dense)               (None, 120)          7320        ['activation_117[0][0]']
#
#  activation_118 (Activation)    (None, 120)          0           ['dense_39[0][0]']
#
#  reshape_18 (Reshape)           (None, 1, 1, 120)    0           ['activation_118[0][0]']
#
#  tf.math.multiply_18 (TFOpLambd  (None, 28, 28, 120)  0          ['activation_116[0][0]',
#  a)                                                               'reshape_18[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 28, 28, 40)   4840        ['tf.math.multiply_18[0][0]']
#
#  batch_normalization_115 (Batch  (None, 28, 28, 40)  160         ['conv2d_77[0][0]']
#  Normalization)
#
#  add_20 (Add)                   (None, 28, 28, 40)   0           ['add_19[0][0]',
#                                                                   'batch_normalization_115[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 28, 28, 240)  9840        ['add_20[0][0]']
#
#  batch_normalization_116 (Batch  (None, 28, 28, 240)  960        ['conv2d_78[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 28, 28, 240)  0           ['batch_normalization_116[0][0]']
#
#  depthwise_conv2d_38 (Depthwise  (None, 14, 14, 240)  2400       ['activation_119[0][0]']
#  Conv2D)
#
#  batch_normalization_117 (Batch  (None, 14, 14, 240)  960        ['depthwise_conv2d_38[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 14, 14, 240)  0           ['batch_normalization_117[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 14, 14, 80)   19280       ['activation_120[0][0]']
#
#  batch_normalization_118 (Batch  (None, 14, 14, 80)  320         ['conv2d_79[0][0]']
#  Normalization)
#
#  conv2d_80 (Conv2D)             (None, 14, 14, 480)  38880       ['batch_normalization_118[0][0]']
#
#  batch_normalization_119 (Batch  (None, 14, 14, 480)  1920       ['conv2d_80[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 14, 14, 480)  0           ['batch_normalization_119[0][0]']
#
#  depthwise_conv2d_39 (Depthwise  (None, 14, 14, 480)  4800       ['activation_121[0][0]']
#  Conv2D)
#
#  batch_normalization_120 (Batch  (None, 14, 14, 480)  1920       ['depthwise_conv2d_39[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 14, 14, 480)  0           ['batch_normalization_120[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 14, 14, 80)   38480       ['activation_122[0][0]']
#
#  batch_normalization_121 (Batch  (None, 14, 14, 80)  320         ['conv2d_81[0][0]']
#  Normalization)
#
#  add_21 (Add)                   (None, 14, 14, 80)   0           ['batch_normalization_118[0][0]',
#                                                                   'batch_normalization_121[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 14, 14, 480)  38880       ['add_21[0][0]']
#
#  batch_normalization_122 (Batch  (None, 14, 14, 480)  1920       ['conv2d_82[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 14, 14, 480)  0           ['batch_normalization_122[0][0]']
#
#  depthwise_conv2d_40 (Depthwise  (None, 14, 14, 480)  4800       ['activation_123[0][0]']
#  Conv2D)
#
#  batch_normalization_123 (Batch  (None, 14, 14, 480)  1920       ['depthwise_conv2d_40[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 14, 14, 480)  0           ['batch_normalization_123[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 14, 14, 80)   38480       ['activation_124[0][0]']
#
#  batch_normalization_124 (Batch  (None, 14, 14, 80)  320         ['conv2d_83[0][0]']
#  Normalization)
#
#  add_22 (Add)                   (None, 14, 14, 80)   0           ['add_21[0][0]',
#                                                                   'batch_normalization_124[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 14, 14, 480)  38880       ['add_22[0][0]']
#
#  batch_normalization_125 (Batch  (None, 14, 14, 480)  1920       ['conv2d_84[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 14, 14, 480)  0           ['batch_normalization_125[0][0]']
#
#  depthwise_conv2d_41 (Depthwise  (None, 14, 14, 480)  4800       ['activation_125[0][0]']
#  Conv2D)
#
#  batch_normalization_126 (Batch  (None, 14, 14, 480)  1920       ['depthwise_conv2d_41[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 14, 14, 480)  0           ['batch_normalization_126[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 14, 14, 80)   38480       ['activation_126[0][0]']
#
#  batch_normalization_127 (Batch  (None, 14, 14, 80)  320         ['conv2d_85[0][0]']
#  Normalization)
#
#  add_23 (Add)                   (None, 14, 14, 80)   0           ['add_22[0][0]',
#                                                                   'batch_normalization_127[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 14, 14, 480)  38880       ['add_23[0][0]']
#
#  batch_normalization_128 (Batch  (None, 14, 14, 480)  1920       ['conv2d_86[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 14, 14, 480)  0           ['batch_normalization_128[0][0]']
#
#  depthwise_conv2d_42 (Depthwise  (None, 14, 14, 480)  4800       ['activation_127[0][0]']
#  Conv2D)
#
#  batch_normalization_129 (Batch  (None, 14, 14, 480)  1920       ['depthwise_conv2d_42[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 14, 14, 480)  0           ['batch_normalization_129[0][0]']
#
#  global_average_pooling2d_21 (G  (None, 480)         0           ['activation_128[0][0]']
#  lobalAveragePooling2D)
#
#  dense_40 (Dense)               (None, 240)          115440      ['global_average_pooling2d_21[0][
#                                                                  0]']
#
#  activation_129 (Activation)    (None, 240)          0           ['dense_40[0][0]']
#
#  dense_41 (Dense)               (None, 480)          115680      ['activation_129[0][0]']
#
#  activation_130 (Activation)    (None, 480)          0           ['dense_41[0][0]']
#
#  reshape_19 (Reshape)           (None, 1, 1, 480)    0           ['activation_130[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None, 14, 14, 480)  0          ['activation_128[0][0]',
#  a)                                                               'reshape_19[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 14, 14, 96)   46176       ['tf.math.multiply_19[0][0]']
#
#  batch_normalization_130 (Batch  (None, 14, 14, 96)  384         ['conv2d_87[0][0]']
#  Normalization)
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 576)  55872       ['batch_normalization_130[0][0]']
#
#  batch_normalization_131 (Batch  (None, 14, 14, 576)  2304       ['conv2d_88[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 14, 14, 576)  0           ['batch_normalization_131[0][0]']
#
#  depthwise_conv2d_43 (Depthwise  (None, 14, 14, 576)  5760       ['activation_131[0][0]']
#  Conv2D)
#
#  batch_normalization_132 (Batch  (None, 14, 14, 576)  2304       ['depthwise_conv2d_43[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 14, 14, 576)  0           ['batch_normalization_132[0][0]']
#
#  global_average_pooling2d_22 (G  (None, 576)         0           ['activation_132[0][0]']
#  lobalAveragePooling2D)
#
#  dense_42 (Dense)               (None, 288)          166176      ['global_average_pooling2d_22[0][
#                                                                  0]']
#
#  activation_133 (Activation)    (None, 288)          0           ['dense_42[0][0]']
#
#  dense_43 (Dense)               (None, 576)          166464      ['activation_133[0][0]']
#
#  activation_134 (Activation)    (None, 576)          0           ['dense_43[0][0]']
#
#  reshape_20 (Reshape)           (None, 1, 1, 576)    0           ['activation_134[0][0]']
#
#  tf.math.multiply_20 (TFOpLambd  (None, 14, 14, 576)  0          ['activation_132[0][0]',
#  a)                                                               'reshape_20[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 96)   55392       ['tf.math.multiply_20[0][0]']
#
#  batch_normalization_133 (Batch  (None, 14, 14, 96)  384         ['conv2d_89[0][0]']
#  Normalization)
#
#  add_24 (Add)                   (None, 14, 14, 96)   0           ['batch_normalization_130[0][0]',
#                                                                   'batch_normalization_133[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 576)  55872       ['add_24[0][0]']
#
#  batch_normalization_134 (Batch  (None, 14, 14, 576)  2304       ['conv2d_90[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 14, 14, 576)  0           ['batch_normalization_134[0][0]']
#
#  depthwise_conv2d_44 (Depthwise  (None, 7, 7, 576)   14976       ['activation_135[0][0]']
#  Conv2D)
#
#  batch_normalization_135 (Batch  (None, 7, 7, 576)   2304        ['depthwise_conv2d_44[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 7, 7, 576)    0           ['batch_normalization_135[0][0]']
#
#  global_average_pooling2d_23 (G  (None, 576)         0           ['activation_136[0][0]']
#  lobalAveragePooling2D)
#
#  dense_44 (Dense)               (None, 288)          166176      ['global_average_pooling2d_23[0][
#                                                                  0]']
#
#  activation_137 (Activation)    (None, 288)          0           ['dense_44[0][0]']
#
#  dense_45 (Dense)               (None, 576)          166464      ['activation_137[0][0]']
#
#  activation_138 (Activation)    (None, 576)          0           ['dense_45[0][0]']
#
#  reshape_21 (Reshape)           (None, 1, 1, 576)    0           ['activation_138[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None, 7, 7, 576)   0           ['activation_136[0][0]',
#  a)                                                               'reshape_21[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 7, 7, 192)    110784      ['tf.math.multiply_21[0][0]']
#
#  batch_normalization_136 (Batch  (None, 7, 7, 192)   768         ['conv2d_91[0][0]']
#  Normalization)
#
#  conv2d_92 (Conv2D)             (None, 7, 7, 1152)   222336      ['batch_normalization_136[0][0]']
#
#  batch_normalization_137 (Batch  (None, 7, 7, 1152)  4608        ['conv2d_92[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 7, 7, 1152)   0           ['batch_normalization_137[0][0]']
#
#  depthwise_conv2d_45 (Depthwise  (None, 7, 7, 1152)  29952       ['activation_139[0][0]']
#  Conv2D)
#
#  batch_normalization_138 (Batch  (None, 7, 7, 1152)  4608        ['depthwise_conv2d_45[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 7, 7, 1152)   0           ['batch_normalization_138[0][0]']
#
#  global_average_pooling2d_24 (G  (None, 1152)        0           ['activation_140[0][0]']
#  lobalAveragePooling2D)
#
#  dense_46 (Dense)               (None, 576)          664128      ['global_average_pooling2d_24[0][
#                                                                  0]']
#
#  activation_141 (Activation)    (None, 576)          0           ['dense_46[0][0]']
#
#  dense_47 (Dense)               (None, 1152)         664704      ['activation_141[0][0]']
#
#  activation_142 (Activation)    (None, 1152)         0           ['dense_47[0][0]']
#
#  reshape_22 (Reshape)           (None, 1, 1, 1152)   0           ['activation_142[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 7, 7, 1152)  0           ['activation_140[0][0]',
#  a)                                                               'reshape_22[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 7, 7, 192)    221376      ['tf.math.multiply_22[0][0]']
#
#  batch_normalization_139 (Batch  (None, 7, 7, 192)   768         ['conv2d_93[0][0]']
#  Normalization)
#
#  add_25 (Add)                   (None, 7, 7, 192)    0           ['batch_normalization_136[0][0]',
#                                                                   'batch_normalization_139[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 7, 7, 1152)   222336      ['add_25[0][0]']
#
#  batch_normalization_140 (Batch  (None, 7, 7, 1152)  4608        ['conv2d_94[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 7, 7, 1152)   0           ['batch_normalization_140[0][0]']
#
#  depthwise_conv2d_46 (Depthwise  (None, 7, 7, 1152)  29952       ['activation_143[0][0]']
#  Conv2D)
#
#  batch_normalization_141 (Batch  (None, 7, 7, 1152)  4608        ['depthwise_conv2d_46[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 7, 7, 1152)   0           ['batch_normalization_141[0][0]']
#
#  global_average_pooling2d_25 (G  (None, 1152)        0           ['activation_144[0][0]']
#  lobalAveragePooling2D)
#
#  dense_48 (Dense)               (None, 576)          664128      ['global_average_pooling2d_25[0][
#                                                                  0]']
#
#  activation_145 (Activation)    (None, 576)          0           ['dense_48[0][0]']
#
#  dense_49 (Dense)               (None, 1152)         664704      ['activation_145[0][0]']
#
#  activation_146 (Activation)    (None, 1152)         0           ['dense_49[0][0]']
#
#  reshape_23 (Reshape)           (None, 1, 1, 1152)   0           ['activation_146[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 7, 7, 1152)  0           ['activation_144[0][0]',
#  a)                                                               'reshape_23[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 7, 7, 192)    221376      ['tf.math.multiply_23[0][0]']
#
#  batch_normalization_142 (Batch  (None, 7, 7, 192)   768         ['conv2d_95[0][0]']
#  Normalization)
#
#  add_26 (Add)                   (None, 7, 7, 192)    0           ['add_25[0][0]',
#                                                                   'batch_normalization_142[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 7, 7, 1152)   222336      ['add_26[0][0]']
#
#  batch_normalization_143 (Batch  (None, 7, 7, 1152)  4608        ['conv2d_96[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 7, 7, 1152)   0           ['batch_normalization_143[0][0]']
#
#  depthwise_conv2d_47 (Depthwise  (None, 7, 7, 1152)  11520       ['activation_147[0][0]']
#  Conv2D)
#
#  batch_normalization_144 (Batch  (None, 7, 7, 1152)  4608        ['depthwise_conv2d_47[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 7, 7, 1152)   0           ['batch_normalization_144[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 7, 7, 320)    368960      ['activation_148[0][0]']
#
#  batch_normalization_145 (Batch  (None, 7, 7, 320)   1280        ['conv2d_97[0][0]']
#  Normalization)
#
#  conv2d_98 (Conv2D)             (None, 7, 7, 1152)   369792      ['batch_normalization_145[0][0]']
#
#  batch_normalization_146 (Batch  (None, 7, 7, 1152)  4608        ['conv2d_98[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 7, 7, 1152)   0           ['batch_normalization_146[0][0]']
#
#  global_average_pooling2d_26 (G  (None, 1152)        0           ['activation_149[0][0]']
#  lobalAveragePooling2D)
#
#  dense_50 (Dense)               (None, 1)            1153        ['global_average_pooling2d_26[0][
#                                                                  0]']
#
# ==================================================================================================
# Total params: 6,293,445
# Trainable params: 6,258,549
# Non-trainable params: 34,896
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss=tf.keras.losses.BinaryCrossentropy(),  
    metrics=['accuracy'] ) 
tb = tf.keras.callbacks.TensorBoard(log_dir='./logs')
checkpoint=tf.keras.callbacks.ModelCheckpoint(filepath='file_name/cp.h5',
                                                 save_weights_only=False,
                                                 verbose=1,
                                                 monitor='val_accuracy',
                                                 save_best_only=True)
EarlyStopping=tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)
# checkpoint = ModelCheckpoint(filepath='file_name',monitor='val_accuracy',mode='auto' ,save_best_only=True,save_freq='epoch')   
early_stop=tf.keras.callbacks.EarlyStopping(patience=patience, monitor = 'val_accuracy')
callback_lists=[tb,checkpoint,early_stop,EarlyStopping]   
history = model.fit(     
                    train_ds,
                    epochs=ePOCH,     
                    validation_data=valid_ds, 
                    verbose=True,
                    callbacks=callback_lists)
